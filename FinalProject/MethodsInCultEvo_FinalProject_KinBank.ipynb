# %% [markdown]
# The goal of this code is to parse the open repository **KinBank**, to retrieve the richness of the kin terminology of the different languages

# %%
# !git clone https://github.com/kinbank/kinbank.git
# Out:
# Cloning into 'kinbank'...
# remote: Enumerating objects: 7404, done.
# remote: Counting objects: 100% (378/378), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 7404 (delta 282), reused 211 (delta 168), pack-reused 7026 (from 1)
# Receiving objects: 100% (7404/7404), 27.17 MiB | 14.85 MiB/s, done.
# Resolving deltas: 100% (5183/5183), done.

# %%
import os
# We
os.chdir('/content/kinbank')
os.chdir('kinbank')
os.chdir('raw')
print(os.getcwd())
# Out:
# /content/kinbank/kinbank/raw

# %%
print(os.listdir())
# Out:
# ['Indo-European', 'Other', 'Atlantic-Congo', 'Pano-Tacanan', 'Salishan', 'Cariban', 'Uto-Aztecan', 'Austronesian', 'Austroasiatic', 'Tupian', 'Dravidian', 'Sino-Tibetan', 'Tai-Kadai', 'sources.bib', 'Nuclear Trans New Guinea', 'Uralic', 'Arawakan', 'Afro-Asiatic', 'Nakh-Daghestanian', 'Algic', 'Pama-Nyungan', 'Turkic']

# %%
from numpy._core.numeric import full
base_path = '/content/kinbank/kinbank/raw'
# This code parse over all the directories and retrieve all the language filenimes over the all
all_files = []

for root, dirs, files in os.walk(base_path):
    for file in files:
        full_path = os.path.join(root, file)
        all_files.append(full_path)
del all_files[0]

all_files[1]
# Out:
# '/content/kinbank/kinbank/raw/Indo-European/Breton_bret1244.csv'

# %%
#This code takes as an input the
def family_language_pair(file_name):
  return file_name.split("/")[-2:]
family_language_pair(all_files[1])
# Out:
# ['Indo-European', 'Breton_bret1244.csv']

# %%
# This code takes as an input the file name and return the name of the language,
# by simply deleting the part
def lang_name(file_name):
  return file_name.rsplit("_", 1)[0]
lang_name(family_language_pair(all_files[1])[1])
# Out:
# 'Breton'

# %%
#This code takes as an input the file name and return the richness of kin terminology,
# The number of the words in the file, because of the file structure is the number of rows
import pandas as pd
def kin_richness(file_name):
  df = pd.read_csv(file_name)
  return len(df)

# %%
# This code gives our final dataset in the form:
# Language family - Language - Richness of the Kin terminology

Data =[]
for language in all_files:
  kin_rich = kin_richness(language)
  language_family = family_language_pair(language)
  language_name = lang_name(language_family[1])
  Data.append([language_family[0], language_name, kin_rich])
Data
# Out:
# /tmp/ipykernel_4643/3169550647.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name)
# [['Indo-European', 'German', 154],
#  ['Indo-European', 'Breton', 490],
#  ['Indo-European', 'Norwegian_Bokmål', 166],
#  ['Indo-European', 'Old_Norse', 160],
#  ['Indo-European', 'Tokharian_A', 24],
#  ['Indo-European', 'Hittite', 182],
#  ['Indo-European', 'Albanian_Tosk_', 180],
#  ['Indo-European', 'English', 154],
#  ['Indo-European', 'Nepali', 584],
#  ['Indo-European', 'Sardinian', 208],
#  ['Indo-European', 'Morgan1871_Hindi', 107],
#  ['Indo-European', 'Saterfriesisch', 234],
#  ['Indo-European', 'Latin', 154],
#  ['Indo-European', 'Boers', 444],
#  ['Indo-European', 'Tok_Pisin', 162],
#  ['Indo-European', 'Western_Panjabi', 488],
#  ['Indo-European', 'Lahnda', 392],
#  ['Indo-European', 'Pashto', 458],
#  ['Indo-European', 'Morgan1871_Bengâli', 107],
#  ['Indo-European', 'Western_Farsi', 274],
#  ['Indo-European', 'Czech', 406],
#  ['Indo-European', 'Torres_Strait_Creole_(Broken)', 162],
#  ['Indo-European', 'Wallon', 172],
#  ['Indo-European', 'Belarusian', 544],
#  ['Indo-European', 'Luxembourgish', 302],
#  ['Indo-European', 'Macedonian', 288],
#  ['Indo-European', 'Eastern_Armenian', 314],
#  ['Indo-European', 'Assamese', 454],
#  ['Indo-European', 'Albanian', 530],
#  ['Indo-European', 'Serbs', 196],
#  ['Indo-European', 'Polish', 760],
#  ['Indo-European', 'Marwari_India_', 209],
#  ['Indo-European', 'Tokharian_B', 30],
#  ['Indo-European', 'Bihari', 195],
#  ['Indo-European', 'Modern_Welsh', 630],
#  ['Indo-European', 'Modern_Greek', 226],
#  ['Indo-European', 'Tajik', 94],
#  ['Indo-European', 'Armenian', 500],
#  ['Indo-European', 'Italian', 202],
#  ['Indo-European', 'Old_Irish', 190],
#  ['Indo-European', 'Latin', 290],
#  ['Indo-European', 'Ossetic', 106],
#  ['Indo-European', 'Bulgarian', 538],
#  ['Indo-European', 'Judeo_Tat', 726],
#  ['Indo-European', 'Jamaican_Creole', 228],
#  ['Indo-European', 'Romanian', 370],
#  ['Indo-European', 'Kumaoni', 575],
#  ['Indo-European', 'Chavacano', 154],
#  ['Indo-European', 'Old_Prussian', 58],
#  ['Indo-European', 'Lithuanian', 506],
#  ['Indo-European', 'Slovakian', 452],
#  ['Indo-European', 'Cornish', 232],
#  ['Indo-European', 'Hindi', 1058],
#  ['Indo-European', 'Ukrainian', 878],
#  ['Indo-European', 'Marathi', 678],
#  ['Indo-European', 'Avestan', 246],
#  ['Indo-European', 'Standard_German', 434],
#  ['Indo-European', 'Slovenian', 182],
#  ['Indo-European', 'Danish', 404],
#  ['Indo-European', 'Latvian', 573],
#  ['Indo-European', 'Morgan1871_Gujarati', 107],
#  ['Indo-European', 'Bengali', 465],
#  ['Indo-European', 'Old_Welsh', 46],
#  ['Indo-European', 'Mahasu_Pahari', 110],
#  ['Indo-European', 'Sinhala', 490],
#  ['Indo-European', 'Kristang_(Malacca_Creole_Portugese)', 161],
#  ['Indo-European', 'Old_Russian', 190],
#  ['Indo-European', 'Morgan1871_Marâthî', 144],
#  ['Indo-European', 'Western_Armenian', 308],
#  ['Indo-European', 'Middle_High_German', 244],
#  ['Indo-European', 'Russian', 162],
#  ['Indo-European', 'Sanskrit', 472],
#  ['Indo-European', 'Kashmiri', 706],
#  ['Indo-European', 'Eastern_Yiddish', 244],
#  ['Indo-European', 'Panjabi', 656],
#  ['Indo-European', 'Oriya', 460],
#  ['Indo-European', 'Northern_Kurdish', 194],
#  ['Indo-European', 'Old_Church_Slavonic', 282],
#  ['Indo-European', 'Swedish', 522],
#  ['Indo-European', 'Old_High_German_ca_750_1050_', 284],
#  ['Indo-European', 'Dutch', 204],
#  ['Indo-European', 'Central_Kurdish', 182],
#  ['Indo-European', 'Standard_Catalan', 316],
#  ['Indo-European', 'Frisian', 660],
#  ['Indo-European', 'Irish', 366],
#  ['Indo-European', 'Standard_Spanish', 220],
#  ['Indo-European', 'Standard_English', 216],
#  ['Indo-European', 'Dari', 508],
#  ['Indo-European', 'Negerhollands', 182],
#  ['Indo-European', 'Gujarati', 842],
#  ['Indo-European', 'Balochi', 232],
#  ['Indo-European', 'Ossetian', 200],
#  ['Indo-European', 'Gothic', 136],
#  ['Indo-European', 'Vlax_Romani', 232],
#  ['Indo-European', 'Old_English_ca_450_1100_', 376],
#  ['Indo-European', 'Urdu', 600],
#  ['Indo-European', 'Russian', 506],
#  ['Indo-European', 'Serbocroation', 580],
#  ['Indo-European', 'Sindhi', 544],
#  ['Indo-European', 'Ancient_Greek', 294],
#  ['Indo-European', 'Portuguese', 178],
#  ['Indo-European', 'Icelandic', 274],
#  ['Indo-European', 'Standard_French', 228],
#  ['Indo-European', 'Eastern_Pahari_Nepali_', 102],
#  ['Indo-European', 'Maithili', 312],
#  ['Indo-European', 'Middle_English', 200],
#  ['Indo-European', 'Kriol_Roper_River', 230],
#  ['Other', 'Kaure', 114],
#  ['Other', 'Tira', 230],
#  ['Other', 'Gününa_Küne', 270],
#  ['Other', 'Kunimaipa', 114],
#  ['Other', 'Foi', 114],
#  ['Other', 'Huli', 162],
#  ['Other', 'Karok', 144],
#  ['Other', 'Loloda-Laba_(Loda)', 77],
#  ['Other', 'Hupa', 106],
#  ['Other', 'Yamana', 186],
#  ['Other', 'Khalkha-Mongolian', 114],
#  ['Other', 'Kamang', 98],
#  ['Other', 'Monumbo', 114],
#  ['Other', 'Umbu-Ungu', 162],
#  ['Other', 'Selk_nam', 186],
#  ['Other', 'Kewa', 162],
#  ['Other', 'Mblafe', 12],
#  ['Other', 'Iyojwa_ja_Chorote', 161],
#  ['Other', 'Morgan1871_Assiniboine_(Asiniboine)', 106],
#  ['Other', 'Nen', 106],
#  ['Other', 'Waffa', 114],
#  ['Other', 'Ebang', 230],
#  ['Other', 'Kanum', 4],
#  ['Other', 'Setaman_Baktamin', 114],
#  ['Other', "I'saka_(Krisa)", 62],
#  ['Other', 'Lake_Miwok', 57],
#  ['Other', 'Isirawa', 114],
#  ['Other', 'Morgan1871_Cherokee', 106],
#  ['Other', 'Bardi', 110],
#  ['Other', 'Kimaama', 114],
#  ['Other', 'Morgan1871_Tuscarora', 106],
#  ['Other', 'Morgan1871_Osage', 104],
#  ['Other', 'Berik', 114],
#  ['Other', 'Gui_(Gwi)', 162],
#  ['Other', 'Tabriak', 349],
#  ['Other', 'Mosetén_Chimané', 98],
#  ['Other', 'Yanomámi', 64],
#  ['Other', 'Muisca_Chibcha_', 112],
#  ['Other', 'Chipaya', 46],
#  ['Other', 'Maybrat', 150],
#  ['Other', 'Eyak', 91],
#  ['Other', 'Morgan1871_Mohawk', 106],
#  ['Other', 'Morgan1871_Two_Mountain_Iroquios', 104],
#  ['Other', 'Kung', 268],
#  ['Other', 'Pumé', 204],
#  ['Other', 'Tulishi', 232],
#  ['Other', 'Telefol', 162],
#  ['Other', 'Madole', 99],
#  ['Other', 'Chiricahua', 200],
#  ['Other', 'Qawasquar', 150],
#  ['Other', 'Japanese', 212],
#  ['Other', 'Basque', 200],
#  ['Other', 'Maklew', 34],
#  ['Other', 'Siwai_Motuna', 114],
#  ['Other', 'Moni', 114],
#  ['Other', 'Amanab', 114],
#  ['Other', 'Lumun', 276],
#  ['Other', 'Wersing', 108],
#  ['Other', 'Korowai', 114],
#  ['Other', 'Epena', 64],
#  ['Other', 'Adang', 99],
#  ['Other', 'Terei', 266],
#  ['Other', 'Morgan1871_Cayuga', 106],
#  ['Other', 'Northern_Embera', 190],
#  ['Other', 'Morgan1871_Tabasco_Chontal_(Chontal_Tabasco)', 42],
#  ['Other', 'Usurufa', 162],
#  ['Other', 'Morgan1871_Dakota_Blackfoot', 106],
#  ['Other', 'Délįne', 188],
#  ['Other', 'Touo', 162],
#  ['Other', 'Tuyuca', 284],
#  ['Other', 'Neme', 79],
#  ['Other', 'Tucano', 178],
#  ['Other', 'Moro', 262],
#  ['Other', 'Western_Apache', 218],
#  ['Other', 'Kilmeri', 114],
#  ['Other', 'Warta_Thuntai', 17],
#  ['Other', 'Morgan1871_Dakota_Isauntie', 106],
#  ['Other', 'Morgan1871_Tukuthe', 100],
#  ['Other', 'Navajo', 158],
#  ['Other', 'Morgan1871_Mountain_Cherokee', 104],
#  ['Other', 'Tidore', 114],
#  ['Other', 'Taiap', 114],
#  ['Other', 'Morgan1871_Punkä', 106],
#  ['Other', 'Morgan1871_Seneca', 106],
#  ['Other', 'Waorani', 260],
#  ['Other', 'Berta', 276],
#  ['Other', 'Abui', 109],
#  ['Other', 'Kunza', 84],
#  ['Other', 'Kuman', 162],
#  ['Other', 'Midob', 162],
#  ['Other', 'Hewa', 162],
#  ['Other', 'Idi', 106],
#  ['Other', 'Morgan1871_Dakota_Yankton', 106],
#  ['Other', 'Wailaki', 154],
#  ['Other', 'Dongola', 256],
#  ['Other', 'Morgan1871_Dakota_Sisseton', 106],
#  ['Other', 'Kogi', 78],
#  ['Other', 'Bari', 298],
#  ['Other', 'Mattole', 47],
#  ['Other', 'Kayardild', 106],
#  ['Other', 'Sanapana', 568],
#  ['Other', 'Teiwa', 98],
#  ['Other', 'Toba', 504],
#  ['Other', 'Morgan1871_Minnitaree', 106],
#  ['Other', 'Wichí', 74],
#  ['Other', 'Western_Pantar', 149],
#  ['Other', 'Onobasulu', 162],
#  ['Other', 'Fore', 114],
#  ['Other', "Morgan1871_Slave_Lake_Indians_or_A-cha'o-tin-ne", 106],
#  ['Other', 'Achuar', 240],
#  ['Other', 'Morgan1871_Tesuque', 56],
#  ['Other', 'Kombai', 114],
#  ['Other', 'Mapudungun', 342],
#  ['Other', 'Nen', 106],
#  ['Other', 'Morgan1871_Dakota_Yanktonais', 106],
#  ['Other', 'Xibe', 162],
#  ['Other', 'Iatmul', 339],
#  ['Other', 'Morgan1871_Onondaga', 106],
#  ['Other', 'Atsugewi', 73],
#  ['Other', 'Zuni', 168],
#  ['Other', 'Morgan1871_Winnebagoe', 106],
#  ['Other', 'Cayubaba', 246],
#  ['Other', 'Tabla', 114],
#  ['Other', 'Angaite', 108],
#  ['Other', 'Morgan1871_Kǔtchin,_or_Louchieux', 99],
#  ['Other', 'Suki', 110],
#  ['Other', 'Gimi', 162],
#  ['Other', 'Yale', 114],
#  ['Other', 'Morgan1871_Kootenay', 68],
#  ['Other', 'Morgan1871_Arikara_(Arickaree)', 90],
#  ['Other', 'Dilling', 244],
#  ['Other', 'Ama', 300],
#  ['Other', 'Pagu', 74],
#  ['Other', 'Ninam', 176],
#  ['Other', 'Cofan', 256],
#  ['Other', 'Edopi', 114],
#  ['Other', 'Shasta', 197],
#  ['Other', 'Morgan1871_Wyandote', 106],
#  ['Other', 'Basque', 284],
#  ['Other', 'Keyagana_(Jate)', 162],
#  ['Other', 'Morgan1871_Kalaallisut_(Eskimo,_Greenland)', 98],
#  ['Other', 'Kwoma', 114],
#  ['Other', 'Komnzo', 224],
#  ['Other', 'Tehuelche', 278],
#  ['Other', 'Elamite', 156],
#  ['Other', 'Nama', 166],
#  ['Other', 'Cusco_Quechua', 268],
#  ['Other', 'NorthMuyu', 114],
#  ['Other', 'Chimariko', 200],
#  ['Other', 'Koalib', 230],
#  ['Other', 'Wipi', 20],
#  ['Other', 'Shilluk', 262],
#  ['Other', 'Morgan1871_Choctaw_(1)', 106],
#  ['Other', 'Kiowa_Apache', 120],
#  ['Other', 'Morgan1871_Mandan', 84],
#  ['Other', 'Morgan1871_Iowä', 106],
#  ['Other', 'DeneTha_South_Slavey_', 226],
#  ['Other', 'Awa', 114],
#  ['Other', 'Tzeltal', 259],
#  ['Other', 'Acoli', 271],
#  ['Other', 'Morgan1871_Chickasa', 106],
#  ['Other', 'Morgan1871_Omahä', 106],
#  ['Other', 'Baruya', 114],
#  ['Other', 'Northern_Haida', 104],
#  ['Other', 'Pilagá', 194],
#  ['Other', 'Dogrib', 114],
#  ['Other', 'Murrinhpatha', 158],
#  ['Other', 'Kalamang', 154],
#  ['Other', 'Miani', 114],
#  ['Other', 'Mocoví', 188],
#  ['Other', 'Sawi', 114],
#  ['Other', 'Central_Aymara', 164],
#  ['Other', 'Tolowa', 140],
#  ['Other', 'Kamano', 162],
#  ['Other', 'Ganggalida', 106],
#  ['Other', 'Morgan1871_Kaw', 106],
#  ['Other', 'Limilngan', 68],
#  ['Other', 'Southern_Coastal_Tsimshian', 184],
#  ['Other', 'Yucatec_Maya', 147],
#  ['Other', 'Meriam', 162],
#  ['Other', 'Aguaruna', 235],
#  ['Other', 'Yelmek', 116],
#  ['Other', 'Nasioi', 114],
#  ['Other', 'Ende_(Papua_New_Guinea)', 179],
#  ['Other', 'Tima', 240],
#  ['Other', 'Buin', 111],
#  ['Other', 'Ketengban', 114],
#  ['Other', 'Nimboran', 114],
#  ['Other', 'Ket', 168],
#  ['Other', 'Nivacle', 266],
#  ['Other', 'Korean', 230],
#  ['Other', 'ASF_Auslan', 162],
#  ['Other', 'Sion', 278],
#  ['Other', 'Galeia_B', 92],
#  ['Other', 'Páez', 190],
#  ['Other', 'Agob-Ende-Kawam', 81],
#  ['Other', 'Morgan1871_Yakama', 78],
#  ['Other', 'Morgan1871_Dakota_Brule', 106],
#  ['Other', 'Negwa_(Yagwoia)', 114],
#  ['Other', 'Blagar', 131],
#  ['Other', 'Coastal_Yuki', 160],
#  ['Other', 'Kiraman', 78],
#  ['Other', 'Hoti_Yuwana_', 58],
#  ['Other', 'Hunza', 383],
#  ['Other', 'Movima', 108],
#  ['Other', 'Morgan1871_Baffin_Inuktitut_(Eskimo,_Northumberland_Inlet)', 106],
#  ['Other', 'Mala', 114],
#  ['Other', 'Nuer', 254],
#  ['Other', 'Yalic', 114],
#  ['Other', 'Dalabon', 106],
#  ['Other', 'Nuu_Chah_Nulth', 122],
#  ['Other', 'Duna', 162],
#  ['Other', 'Northern_Pomo', 153],
#  ['Other', "Morgan1871_Red-knife,_or_Täl-sote'e-nä", 106],
#  ['Other', 'Cha_palaa', 104],
#  ['Other', 'Mairasi', 114],
#  ['Other', 'Tucanoan_Bará', 103],
#  ['Other', 'Cocopa', 145],
#  ['Other', 'Koiari', 158],
#  ['Other', 'Kiwaian', 114],
#  ['Other', 'Au', 146],
#  ['Other', 'Yuracare', 114],
#  ['Other', 'Korafe', 114],
#  ['Other', 'Jingulu', 111],
#  ['Other', 'Bininj_Kun-wok', 139],
#  ['Other', 'Orokolo', 292],
#  ['Other', 'Daribi', 162],
#  ['Other', 'Jicarilla', 262],
#  ['Other', 'SepikIwam', 286],
#  ['Other', 'Cruzeño', 24],
#  ['Other', 'Degexit_an', 24],
#  ['Other', 'Rotokas', 162],
#  ['Other', 'Copper_Inuit', 234],
#  ['Other', 'Momu-Fas', 114],
#  ['Other', 'SoutheasternDinka', 247],
#  ['Other', 'Meyah', 106],
#  ['Other', 'Lardil', 162],
#  ['Other', 'Riantana', 17],
#  ['Other', 'Morgan1871_Oneida', 106],
#  ['Other', 'Trumai', 88],
#  ['Other', 'Morgan1871_Crow', 106],
#  ['Other', 'Wari_', 8],
#  ['Other', 'Kuot', 109],
#  ['Other', 'Tsafiki', 78],
#  ['Other', 'Galeia_A', 96],
#  ['Other', 'Wambaya', 154],
#  ['Other', 'Ngile', 246],
#  ['Other', 'Bilua', 162],
#  ['Other', 'Bari', 268],
#  ['Other', 'Puinave', 106],
#  ['Other', 'Yele_(Yélî_Dnye)', 162],
#  ['Other', 'Nagovisi', 114],
#  ['Other', 'Morgan1871_Dakota_Uncpapa', 106],
#  ['Other', 'Doutai', 114],
#  ['Other', 'Nyulnyul', 152],
#  ['Other', 'Karko', 274],
#  ['Other', 'Dene_Suliné', 226],
#  ['Other', 'Seri', 290],
#  ['Other', 'Quechan', 125],
#  ['Other',
#   "Morgan1871_Western_Canadian_Inuktitut_(Eskimo,_West_of_Hudson's_Bay)",
#   38],
#  ['Other', 'Marind', 160],
#  ['Other', 'Morgan1871_Chibcha_(New_Granada)', 74],
#  ['Other', 'Tlingit', 102],
#  ['Other', 'Klon', 38],
#  ['Other', 'Itonama', 174],
#  ['Other', 'Iwam', 114],
#  ['Other', 'Konda_(Western_Dani)', 114],
#  ['Other', 'Yukulta_(Ganggalida)', 115],
#  ['Other', 'Awiakay', 114],
#  ['Other', 'Morgan1871_Creek', 106],
#  ['Other', 'Morgan1871_Choctaw_(2)', 106],
#  ['Other', 'Morgan1871_Laguna', 51],
#  ['Other', 'Morgan1871_Republican_Pawnee', 106],
#  ['Other', 'Marra', 230],
#  ['Other', 'Ayoreo', 224],
#  ['Other', 'Alamblak', 114],
#  ['Other', 'Mali', 44],
#  ['Other', 'Netsilik', 230],
#  ['Other', 'Wappo', 106],
#  ['Other', 'Ekari', 114],
#  ['Other', "Morgan1871_Hare_Indians_or_Tä-nä'-tin-ne", 106],
#  ['Other', 'Sougb', 106],
#  ['Other', 'Northeastern_Maidu', 233],
#  ['Other', 'Northwestern_Maidu', 194],
#  ['Other', 'Morgan1871_Grand_Pawnee', 104],
#  ['Other', 'Krongo', 232],
#  ['Other', 'Morgan1871_Dakota_Ogalalla', 106],
#  ['Other', 'Iau', 114],
#  ['Other', 'Morgan1871_Otoe', 106],
#  ['Other', 'Nunamiut', 250],
#  ['Other', 'Eipo', 162],
#  ['Other', 'Inanwatan_(Suabo)', 111],
#  ['Other', 'Watam', 114],
#  ['Other', 'Savosavo', 162],
#  ['Other', 'Lengua', 168],
#  ['Other', 'Morgan1871_Japanese', 107],
#  ['Other', 'Yawa', 114],
#  ['Other', 'Nambo', 112],
#  ['Other', 'Maca', 121],
#  ['Other', 'Kashaya', 114],
#  ['Other', 'Grand_Valley_Dani', 114],
#  ['Other', 'Nungon', 114],
#  ['Other', 'Kemiju_(Jate)', 162],
#  ['Other', 'Lipan_Apache', 196],
#  ['Other', 'Cubeo', 294],
#  ['Other', 'Yuki', 104],
#  ['Other', 'Kemtuik', 114],
#  ['Atlantic-Congo', 'Bushoong', 222],
#  ['Atlantic-Congo', 'Rundi', 258],
#  ['Atlantic-Congo', 'Fang_EG', 210],
#  ['Atlantic-Congo', 'Ding', 492],
#  ['Atlantic-Congo', 'Phende', 282],
#  ['Atlantic-Congo', 'Vili', 7],
#  ['Atlantic-Congo', 'Lala_Bisa', 68],
#  ['Atlantic-Congo', 'Bila', 204],
#  ['Atlantic-Congo', 'Haya', 200],
#  ['Atlantic-Congo', 'Tsogo', 62],
#  ['Atlantic-Congo', 'Kamba', 303],
#  ['Atlantic-Congo', 'Nyoro', 234],
#  ['Atlantic-Congo', 'Yaka_CAR_', 230],
#  ['Atlantic-Congo', 'Ngulu', 191],
#  ['Atlantic-Congo', 'Kwasio', 231],
#  ['Atlantic-Congo', 'Yaka_Pelende_Lonzo', 182],
#  ['Atlantic-Congo', 'Temi', 34],
#  ['Atlantic-Congo', 'Oroko', 26],
#  ['Atlantic-Congo', 'Tetela', 192],
#  ['Atlantic-Congo', 'Bali_DRC_', 24],
#  ['Atlantic-Congo', 'Kikuyu', 222],
#  ['Atlantic-Congo', 'Mbere', 59],
#  ['Atlantic-Congo', 'Kélé', 14],
#  ['Atlantic-Congo', 'Tswana', 183],
#  ['Atlantic-Congo', 'Taabwa', 121],
#  ['Atlantic-Congo', 'Suundi', 106],
#  ['Atlantic-Congo', 'Venda', 120],
#  ['Atlantic-Congo', 'Tsonga', 186],
#  ['Atlantic-Congo', 'Suku', 336],
#  ['Atlantic-Congo', 'Morgan1871_Amazulu_(Amazulu_Kafir)', 107],
#  ['Atlantic-Congo', 'Budza', 30],
#  ['Atlantic-Congo', 'Duala', 266],
#  ['Atlantic-Congo', 'Bamun', 18],
#  ['Atlantic-Congo', 'Sangu', 14],
#  ['Atlantic-Congo', 'San_Salvador_Kongo', 192],
#  ['Atlantic-Congo', 'Bukusu', 278],
#  ['Atlantic-Congo', 'Kagulu', 180],
#  ['Atlantic-Congo', 'Mongo', 318],
#  ['Atlantic-Congo', 'Masaaba', 177],
#  ['Atlantic-Congo', 'Tsaangi', 7],
#  ['Atlantic-Congo', 'Bena_Tanzania_', 268],
#  ['Atlantic-Congo', 'Myene', 283],
#  ['Atlantic-Congo', 'Zulu', 191],
#  ['Atlantic-Congo', 'Kerewe', 87],
#  ['Atlantic-Congo', 'Lamba', 192],
#  ['Atlantic-Congo', 'Njebi', 42],
#  ['Atlantic-Congo', 'Tonga_Nyasa_', 151],
#  ['Atlantic-Congo', 'Bera', 180],
#  ['Atlantic-Congo', 'Tooro', 184],
#  ['Atlantic-Congo', 'Hehe', 186],
#  ['Atlantic-Congo', 'Bafia', 36],
#  ['Atlantic-Congo', 'Nyakyusa', 147],
#  ['Atlantic-Congo', 'Bende', 174],
#  ['Atlantic-Congo', 'Kaonde', 176],
#  ['Atlantic-Congo', 'Zigula', 146],
#  ['Atlantic-Congo', 'Mungaka', 116],
#  ['Atlantic-Congo', 'Gogo', 203],
#  ['Atlantic-Congo', 'Gusii', 151],
#  ['Atlantic-Congo', 'Sake', 22],
#  ['Atlantic-Congo', 'Mbala', 358],
#  ['Atlantic-Congo', 'Shi', 180],
#  ['Atlantic-Congo', 'Yombe', 170],
#  ['Atlantic-Congo', 'Soga', 302],
#  ['Atlantic-Congo', 'Nsong', 232],
#  ['Atlantic-Congo', 'Sira', 14],
#  ['Atlantic-Congo', 'Shona', 10],
#  ['Atlantic-Congo', 'Bali_Congo_', 9],
#  ['Atlantic-Congo', 'Batanga', 228],
#  ['Atlantic-Congo', 'Lingala', 332],
#  ['Atlantic-Congo', 'Ha', 228],
#  ['Atlantic-Congo', 'Ndumu', 11],
#  ['Atlantic-Congo', 'Fefe', 324],
#  ['Atlantic-Congo', 'Luguru', 242],
#  ['Atlantic-Congo', 'Duma', 14],
#  ['Atlantic-Congo', 'Sukuma', 96],
#  ['Atlantic-Congo', 'Avatime', 48],
#  ['Atlantic-Congo', 'Songoora', 105],
#  ['Atlantic-Congo', 'Giryama', 196],
#  ['Atlantic-Congo', 'Umbundu', 228],
#  ['Atlantic-Congo', 'Bemba', 142],
#  ['Atlantic-Congo', 'Yao', 8],
#  ['Atlantic-Congo', 'Sumbwa', 72],
#  ['Atlantic-Congo', 'Kota', 66],
#  ['Atlantic-Congo', 'Luba_Katanga', 128],
#  ['Atlantic-Congo', 'Digo', 196],
#  ['Atlantic-Congo', 'Mbuun', 220],
#  ['Atlantic-Congo', 'Mokpwe', 438],
#  ['Atlantic-Congo', 'Sango', 91],
#  ['Atlantic-Congo', 'Tiv', 186],
#  ['Atlantic-Congo', 'Lozi', 182],
#  ['Atlantic-Congo', 'Meru', 242],
#  ['Atlantic-Congo', 'Meta', 37],
#  ['Atlantic-Congo', 'Punu', 45],
#  ['Atlantic-Congo', 'Fipa', 186],
#  ['Atlantic-Congo', 'Kwere', 158],
#  ['Atlantic-Congo', 'Ngombe_Binja', 17],
#  ['Atlantic-Congo', 'Ekonda_Mongo', 191],
#  ['Atlantic-Congo', 'Yansi', 97],
#  ['Atlantic-Congo', 'Ganda', 181],
#  ['Atlantic-Congo', 'Herero', 306],
#  ['Atlantic-Congo', 'Seki', 22],
#  ['Atlantic-Congo', 'Makonde', 422],
#  ['Atlantic-Congo', 'Luba_Lulua', 322],
#  ['Atlantic-Congo', 'Igbo', 124],
#  ['Atlantic-Congo', 'Kom', 196],
#  ['Atlantic-Congo', 'Langi', 278],
#  ['Atlantic-Congo', 'Pokomo', 28],
#  ['Atlantic-Congo', 'Luvale', 176],
#  ['Atlantic-Congo', 'Lunda', 182],
#  ['Atlantic-Congo', 'Komo_DRC_', 393],
#  ['Atlantic-Congo', 'Sangu_Tanzania_', 158],
#  ['Atlantic-Congo', 'Zinza', 86],
#  ['Atlantic-Congo', 'Pinji', 60],
#  ['Atlantic-Congo', 'Ngoni', 94],
#  ['Atlantic-Congo', 'Asu_Tanzania_', 198],
#  ['Atlantic-Congo', 'Chokwe', 192],
#  ['Atlantic-Congo', 'Sakata', 120],
#  ['Pano-Tacanan', 'Shipibo', 289],
#  ['Salishan', 'Morgan1871_Okinaken', 48],
#  ['Salishan', 'Morgan1871_Spokäne', 88],
#  ['Cariban', 'Waimiri_Atroari', 230],
#  ['Cariban', 'De_kwana_Maquiritari_', 258],
#  ['Cariban', 'Macushi', 372],
#  ['Cariban', 'Wai_Wai', 168],
#  ['Cariban', 'Pemon', 258],
#  ['Cariban', 'Galibi_Carib', 288],
#  ['Cariban', 'Panare', 457],
#  ['Uto-Aztecan', 'Southern_Tepehuan', 33],
#  ['Uto-Aztecan', 'Hopi_S_', 44],
#  ['Uto-Aztecan', 'Mayo', 41],
#  ['Uto-Aztecan', 'Cupeño', 212],
#  ['Uto-Aztecan', 'Northern_Paiute', 40],
#  ['Uto-Aztecan', 'Huastec_Nahuatl', 16],
#  ['Uto-Aztecan', 'Comanche', 251],
#  ['Uto-Aztecan', 'Pipil', 19],
#  ['Uto-Aztecan', 'Southern_Ute', 91],
#  ['Uto-Aztecan', 'Southern_Tepehuan_W_', 6],
#  ['Uto-Aztecan', 'Southeastern_Tepehuano', 374],
#  ['Uto-Aztecan', 'Tubar', 21],
#  ['Uto-Aztecan', 'Aztec', 136],
#  ['Uto-Aztecan', 'Shoshoni', 58],
#  ['Uto-Aztecan', 'Western_Shoshoni', 18],
#  ['Uto-Aztecan', 'Serrano', 234],
#  ['Uto-Aztecan', 'Nevome', 8],
#  ['Uto-Aztecan', 'Colorado_Ute', 42],
#  ['Uto-Aztecan', 'Hopi', 69],
#  ['Uto-Aztecan', 'Bannock', 132],
#  ['Uto-Aztecan', 'Cahuilla', 222],
#  ['Uto-Aztecan', 'Southern_Paiute', 72],
#  ['Uto-Aztecan', 'Gabrielino', 67],
#  ['Uto-Aztecan', 'Lower_Pima_Pima_Bajo', 27],
#  ['Uto-Aztecan', 'Guarijio', 64],
#  ['Uto-Aztecan', 'Cora', 45],
#  ['Uto-Aztecan', 'Kitanemuk', 69],
#  ['Uto-Aztecan', 'Luiseńo', 303],
#  ['Uto-Aztecan', 'Tarahumara', 292],
#  ['Uto-Aztecan', 'Yaqui', 94],
#  ['Uto-Aztecan', 'Tümpisha_Shoshoni', 192],
#  ['Uto-Aztecan', 'Tübatülabal', 32],
#  ['Uto-Aztecan', 'Pima_de_Yepáchic', 14],
#  ['Uto-Aztecan', 'Opata', 218],
#  ['Uto-Aztecan', 'Tohono_O_odham', 49],
#  ['Uto-Aztecan', 'Eudeve', 42],
#  ['Uto-Aztecan', 'Kawaiisu', 40],
#  ['Uto-Aztecan', 'Chemehuevi', 118],
#  ['Uto-Aztecan', 'North_Northern_Paiute', 231],
#  ['Uto-Aztecan', 'Arizona_Yaqui', 16],
#  ['Uto-Aztecan', 'Northern_Tepehuan', 41],
#  ['Uto-Aztecan', 'Highland_Puebla_Nahuatl', 162],
#  ['Uto-Aztecan', 'Huichol', 20],
#  ['Uto-Aztecan', 'White_Mesa_Ute', 29],
#  ['Uto-Aztecan', 'Morgan1871_Utahs_(Tabegwaches)', 57],
#  ['Uto-Aztecan', 'Mono', 176],
#  ['Austronesian', 'Pama_(Paamanese)', 70],
#  ['Austronesian', 'Alangan', 154],
#  ['Austronesian', 'Pendau', 154],
#  ['Austronesian', 'West_Futuna', 158],
#  ['Austronesian', 'Maguindanao_(Magindonao_Moro)', 158],
#  ['Austronesian', 'Futuna-Aniwa', 111],
#  ['Austronesian', 'Barok_(Karu)', 67],
#  ['Austronesian', 'Mekeo_(North)', 9],
#  ['Austronesian', 'Big_Nambas', 90],
#  ['Austronesian', 'Talibabu', 80],
#  ['Austronesian', 'Luangiua_(Ontong_Java)', 162],
#  ['Austronesian', 'Hanunoo', 154],
#  ['Austronesian', 'Sonsorol', 113],
#  ['Austronesian', 'Raga_(Hano)', 105],
#  ['Austronesian', 'Hawaii', 154],
#  ['Austronesian', 'Raga_(Hano_Thomas_Ennever)', 115],
#  ['Austronesian', 'Sungwaloge_(Tawet)', 154],
#  ['Austronesian', 'Daakie', 70],
#  ['Austronesian', 'Rakahanga-Manihiki', 106],
#  ['Austronesian', 'Easter_Islanders', 178],
#  ['Austronesian', 'Fijian', 162],
#  ['Austronesian', 'South_Tuvaluan_(Vaitupu)', 162],
#  ['Austronesian', 'Patani', 108],
#  ['Austronesian', 'Mori_Bawah', 146],
#  ['Austronesian', 'Tuvalu_(Nanumea)', 158],
#  ['Austronesian', 'Kapingamarangi', 162],
#  ['Austronesian', 'Nehan', 146],
#  ['Austronesian', 'Carolinians', 16],
#  ['Austronesian', 'Lewo', 33],
#  ['Austronesian', 'Sungwadaga', 149],
#  ['Austronesian', 'Urak_Lawoi', 82],
#  ['Austronesian', 'Nage', 114],
#  ['Austronesian', 'Nahavaq', 74],
#  ['Austronesian', 'Colloquial_Malay', 260],
#  ['Austronesian', 'Dondo', 154],
#  ['Austronesian', 'Southeast_Ambrym', 141],
#  ['Austronesian', 'Maba_(Indonesia)', 104],
#  ['Austronesian', 'Dobu', 109],
#  ['Austronesian', 'Bario_Kelabit', 162],
#  ['Austronesian', 'Ampibabo_Lauje', 152],
#  ['Austronesian', 'Penrhyn_(Tongareva)', 106],
#  ['Austronesian', 'Buhid', 154],
#  ['Austronesian', 'Sunwadia', 74],
#  ['Austronesian', 'Lala', 254],
#  ['Austronesian', 'East_Ambae_(Lolovoli)', 48],
#  ['Austronesian', 'Central_Tagbanwa', 140],
#  ['Austronesian', 'Roviana', 162],
#  ['Austronesian', 'Pukapuka', 162],
#  ['Austronesian', 'Owa_(Santa_Ana)', 108],
#  ['Austronesian', 'Vures', 106],
#  ['Austronesian', 'Ayiwo', 154],
#  ['Austronesian', 'Bunun', 122],
#  ['Austronesian', 'Toqabaqita', 144],
#  ['Austronesian', 'Lamahalot', 26],
#  ['Austronesian', 'Achinese', 78],
#  ['Austronesian', 'Mangei_(Sobjo)', 76],
#  ['Austronesian', 'Indonesian_Bajau', 162],
#  ['Austronesian', 'Tikopia', 162],
#  ['Austronesian', 'Kwamera', 114],
#  ['Austronesian', 'Rade_(Rhade)', 110],
#  ['Austronesian', 'Ilokano', 162],
#  ['Austronesian', 'Matukar', 169],
#  ['Austronesian', 'Kiput', 148],
#  ['Austronesian', 'Bwaidoga', 11],
#  ['Austronesian', 'Manam', 99],
#  ['Austronesian', 'Sundanese', 110],
#  ['Austronesian', 'Palauan', 118],
#  ['Austronesian', 'Titan', 293],
#  ['Austronesian', 'Sungwadia', 152],
#  ['Austronesian', 'Tadyawan', 154],
#  ['Austronesian', 'Waru', 50],
#  ['Austronesian', 'Tahitian', 113],
#  ['Austronesian', 'Mono-Alu', 56],
#  ['Austronesian', "Tokotu'a_(Kabaena)", 50],
#  ['Austronesian', 'Tonsea', 154],
#  ['Austronesian', 'Lenakel', 114],
#  ['Austronesian', 'North_Efate_(Nguna,_Nakanamanga)', 75],
#  ['Austronesian', 'Old_Javanese_(Kawi)', 126],
#  ['Austronesian', 'Morgan1871_Hawaiian', 107],
#  ['Austronesian', 'Tagalog', 160],
#  ['Austronesian', 'Dampelas', 158],
#  ['Austronesian', 'Kankanay', 54],
#  ['Austronesian', 'Lau', 96],
#  ['Austronesian', 'Nyindrou', 234],
#  ['Austronesian', 'Talise_(Tolo)', 162],
#  ['Austronesian', 'Hiw', 48],
#  ['Austronesian', 'Asera', 50],
#  ['Austronesian', 'Kalinga_(Ahin-Kayapa_Kalanguya)', 144],
#  ['Austronesian', 'Weda', 92],
#  ['Austronesian', 'Lonwolwol', 62],
#  ['Austronesian', 'Madak_(Konnos)', 90],
#  ['Austronesian', 'Tonga_(Tonga_Islands)', 106],
#  ['Austronesian', 'Konawe', 50],
#  ['Austronesian', 'Takuu', 142],
#  ['Austronesian', 'Māori', 369],
#  ['Austronesian', 'Senbarei', 92],
#  ['Austronesian', 'Itneg_(Binongan)', 114],
#  ['Austronesian', 'Rahambuu', 50],
#  ['Austronesian', 'Lo-Toga_(Loh)', 150],
#  ['Austronesian', 'Dakaka', 136],
#  ['Austronesian', 'Tajio', 158],
#  ['Austronesian', 'Tolaki', 146],
#  ['Austronesian', 'Emae_(Mae)', 21],
#  ['Austronesian', 'Tanampedagi_Taje', 154],
#  ['Austronesian', 'Nguna', 127],
#  ['Austronesian', 'Halia', 235],
#  ['Austronesian', 'Ibaloi_(Nabaloi)', 162],
#  ['Austronesian', 'Iraya', 154],
#  ['Austronesian', "Riuk_Bekati'_(Dayak)", 36],
#  ['Austronesian', "Vera'a", 111],
#  ['Austronesian', 'Cotabato_Manobo', 114],
#  ['Austronesian', "'Are'are", 138],
#  ['Austronesian', 'Puyuma', 36],
#  ['Austronesian', 'Zabana_(Kia)', 59],
#  ['Austronesian', 'Tanala', 360],
#  ['Austronesian', 'Rotinese_Termanu_', 183],
#  ['Austronesian', 'Kankanaey_(Kankanai)', 150],
#  ['Austronesian', 'Namakura', 33],
#  ['Austronesian', 'Nias', 534],
#  ['Austronesian', 'Atta', 114],
#  ['Austronesian', 'Numbami', 104],
#  ['Austronesian', 'Gane_(Gimán)', 108],
#  ['Austronesian', 'Gapapaiwa', 247],
#  ['Austronesian', 'Sungagage', 117],
#  ['Austronesian', 'Petapa_Taje', 74],
#  ['Austronesian', 'Yami_Tao_', 146],
#  ['Austronesian', 'Luburua_(Kara)', 66],
#  ['Austronesian', 'Sawai', 108],
#  ['Austronesian', 'Vao', 96],
#  ['Austronesian', 'Nengone', 107],
#  ['Austronesian', 'Totoli', 154],
#  ['Austronesian', 'Varisi', 112],
#  ['Austronesian', 'Lauje', 158],
#  ['Austronesian', 'Maori', 110],
#  ['Austronesian', 'Rangiora_(NW_Tuamotus)', 114],
#  ['Austronesian', 'Maskelynes', 57],
#  ['Austronesian', 'Bungku', 146],
#  ['Austronesian', 'Mori_Atas', 50],
#  ['Austronesian', 'Lele', 292],
#  ['Austronesian', 'Morgan1871_Maori', 76],
#  ['Austronesian', 'Bahonsuai', 50],
#  ['Austronesian', "Neve'ei", 43],
#  ['Austronesian', 'Magam', 61],
#  ['Austronesian', 'Wallisian_(East_Uvea)', 104],
#  ['Austronesian', 'Old_Rapa_(Rapa)', 114],
#  ['Austronesian', 'Saaroa', 138],
#  ['Austronesian', 'Sungwaloge_(Nalemba_Edward)', 158],
#  ['Austronesian', 'Mekeo_(East)', 9],
#  ['Austronesian', 'Sula_Mangoli', 76],
#  ['Austronesian', 'North_Tanna', 122],
#  ['Austronesian', 'Bacanese_Malay_(Bacan)', 106],
#  ['Austronesian', 'Kodeoha', 50],
#  ['Austronesian', 'Paluai', 114],
#  ['Austronesian', 'Atoni_(Uab_Meto)', 132],
#  ['Austronesian', 'Rennell_Islanders', 195],
#  ['Austronesian', "Neve'ei", 95],
#  ['Austronesian', 'Naman', 90],
#  ['Austronesian', 'Kuanua', 162],
#  ['Austronesian', 'Dehu', 38],
#  ['Austronesian', 'Whitesands', 122],
#  ['Austronesian', 'Pangasinan', 117],
#  ['Austronesian', 'Paiwan', 162],
#  ['Austronesian', 'Ifaluk_Nuclear_Woleaian_', 134],
#  ['Austronesian', 'Lalomerui', 50],
#  ['Austronesian', 'Miningir_(Lunga)', 158],
#  ['Austronesian', 'Taumako', 110],
#  ['Austronesian', 'Niueans', 152],
#  ['Austronesian', 'Banjar', 162],
#  ['Austronesian', 'Bilibil', 154],
#  ['Austronesian', 'Tausug_(Sulu_Moro)', 128],
#  ['Austronesian', "Brooke's_Point_Palawano", 142],
#  ['Austronesian', 'Mungiki_(Bellona)', 36],
#  ['Austronesian', 'Sungwaloge_(Tauta)', 154],
#  ['Austronesian', 'Uma_Juman_(Kayan)', 162],
#  ['Austronesian', 'Ellice', 194],
#  ['Austronesian', 'Tahitians', 165],
#  ['Austronesian', 'Puluwatese_(Puluwat)', 142],
#  ['Austronesian', 'Koroni', 50],
#  ['Austronesian', 'Marquesas', 113],
#  ['Austronesian', 'Unua', 39],
#  ['Austronesian', 'Tetum_(Tetun)', 90],
#  ['Austronesian', 'Tokelau', 151],
#  ['Austronesian', 'Hawaiians', 404],
#  ['Austronesian', 'Mekeo_(North-West)', 9],
#  ['Austronesian', 'Ura', 48],
#  ['Austronesian', 'Mangaia', 112],
#  ['Austronesian', 'Raroians', 194],
#  ['Austronesian', 'Maranao_(Lanao_Moro)', 121],
#  ['Austronesian', 'Central_Sama', 154],
#  ['Austronesian', 'Malua_Bay', 116],
#  ['Austronesian', 'Tiale', 14],
#  ['Austronesian', 'Javanese', 162],
#  ['Austronesian', 'Mekongga', 50],
#  ['Austronesian', 'Amis', 46],
#  ['Austronesian', 'Hiligaynon', 162],
#  ['Austronesian', 'Bukat', 162],
#  ['Austronesian', 'Casiguran_Dumagat_Agta', 162],
#  ['Austronesian', 'Rejang_(Rejangese)', 154],
#  ['Austronesian', "Niuafo'ou", 58],
#  ['Austronesian', 'Nese', 64],
#  ['Austronesian', 'Chamarro', 158],
#  ['Austronesian', 'North_Ambrym', 74],
#  ['Austronesian', 'Sie_(Sye)', 112],
#  ['Austronesian', 'Nalik_(Lukuramau)', 95],
#  ['Austronesian', 'Ratagnon', 154],
#  ['Austronesian', 'Kapingamarangi', 196],
#  ['Austronesian', 'Wolio', 56],
#  ['Austronesian', 'Rotuman', 106],
#  ['Austronesian', 'Tulambatu', 50],
#  ['Austronesian', 'Central_Subanen_(Subanung)', 37],
#  ['Austronesian', 'Ibanag', 162],
#  ['Austronesian', 'Kambera', 162],
#  ['Austronesian', 'Lametin', 8],
#  ['Austronesian', 'Loniu', 86],
#  ['Austronesian', 'Balangao', 114],
#  ['Austronesian', 'West_Coast_Bajau', 162],
#  ['Austronesian', 'Neverver', 146],
#  ['Austronesian', 'Kwaio', 114],
#  ['Austronesian', 'Ifugaw_(Ifugao)', 81],
#  ['Austronesian', 'Waropen', 110],
#  ['Austronesian', 'Wedau', 272],
#  ['Austronesian', 'Menui', 50],
#  ['Austronesian', 'Kodi', 42],
#  ['Austronesian', 'Western_Tawbuid_(Batangan)', 154],
#  ['Austronesian', 'Araki', 142],
#  ['Austronesian', 'Bierebo', 51],
#  ['Austronesian', 'Mortlockese', 116],
#  ['Austronesian', 'Tubuai', 114],
#  ['Austronesian', 'Pohnpeian', 101],
#  ['Austronesian', 'MisimaPaneati', 234],
#  ['Austronesian', 'East_Futuna', 150],
#  ['Austronesian', 'Routa', 50],
#  ['Austronesian', 'Wiwirano', 50],
#  ['Austronesian', 'Batak_Toba', 113],
#  ['Austronesian', 'South_Marquesan', 122],
#  ['Austronesian', 'Woleaian', 36],
#  ['Austronesian', 'Proto-Oceanic', 56],
#  ['Austronesian', 'Tamambo', 81],
#  ['Austronesian', 'Cebuano', 158],
#  ['Austronesian', 'Southeast_Babar', 30],
#  ['Austronesian', 'Tiang', 327],
#  ['Austronesian', 'BatakKaro', 368],
#  ['Austronesian', 'Merlav', 92],
#  ['Austronesian', 'Mangareva', 113],
#  ['Austronesian', 'Larevat', 90],
#  ['Austronesian', 'Buru_(Indonesia)', 79],
#  ['Austronesian', 'Gela', 114],
#  ['Austronesian', 'Avava_(Niviar_Dialect)', 102],
#  ['Austronesian', 'Namakura', 158],
#  ['Austronesian', 'Tokelau', 210],
#  ['Austronesian', 'Maragus_(Tape)', 58],
#  ['Austronesian', 'Torete', 50],
#  ['Austronesian', 'Niue', 94],
#  ['Austronesian', 'Tirax_(Mae)', 71],
#  ['Austronesian', 'Yabem', 161],
#  ['Austronesian', 'Letemboi-Repanbitip', 107],
#  ['Austronesian', "Ga'dang", 162],
#  ['Austronesian', 'Central_Melanau', 161],
#  ['Austronesian', 'Tigak', 18],
#  ['Austronesian', 'Laiwui', 50],
#  ['Austronesian', 'Morgan1871_Kings_Mill_Islands', 101],
#  ['Austronesian', 'Big_Nambas', 91],
#  ['Austronesian', 'Watut', 154],
#  ['Austronesian', 'Sika', 18],
#  ['Austronesian', 'Aria_(Mouk-Aria)', 96],
#  ['Austronesian', 'Southwest_Tanna', 126],
#  ['Austronesian', 'Wuvulu_Aua', 184],
#  ['Austronesian', 'Motu', 114],
#  ['Austronesian', 'Wogeo', 114],
#  ['Austronesian', 'Tialo_(Tomini)', 154],
#  ['Austronesian', 'Brunei-Sabah_Malay_(Malay)', 155],
#  ['Austronesian', "Ili'uun", 108],
#  ['Austronesian', 'Mekeo', 20],
#  ['Austronesian', 'Butmas-Tur', 86],
#  ['Austronesian', 'Futunans', 282],
#  ['Austronesian', 'Mouk', 131],
#  ['Austronesian', 'Cheke_Holo', 83],
#  ['Austronesian', 'Xaracuu_(Canala)', 61],
#  ['Austronesian', 'Rapanui_(Easter_Island)', 81],
#  ['Austronesian', 'Rarotongan_(Cook_Islands_Maori)', 154],
#  ['Austronesian', 'Tikopia', 195],
#  ['Austronesian', 'Western_Bukidnon_Manobo', 162],
#  ['Austronesian', 'Bannoni', 162],
#  ['Austronesian', 'Biak', 108],
#  ['Austronesian', 'Anejom', 160],
#  ['Austronesian', 'Emau_(Emao_Island)', 133],
#  ['Austronesian', 'Ontong_Java', 277],
#  ['Austronesian', 'Takia', 162],
#  ['Austronesian', 'Yamdena', 234],
#  ['Austronesian', 'Tombulu', 162],
#  ['Austronesian', 'Sikaiana', 144],
#  ['Austronesian', 'Madurese', 162],
#  ['Austronesian', 'Xalangi_(Maevo_Vanuatu)', 158],
#  ['Austronesian', 'Lamogai', 26],
#  ['Austronesian', 'Yakan', 162],
#  ['Austronesian', 'Atchin', 122],
#  ['Austronesian', 'Mussau-Emira', 114],
#  ['Austronesian', 'Port_Sandwich', 123],
#  ['Austronesian', 'Rotumans', 280],
#  ['Austronesian', 'Balaesang', 71],
#  ['Austronesian', 'Lavatbura-lamusong_(Konobin)', 64],
#  ['Austronesian', 'Moronene', 146],
#  ['Austronesian', 'Tausug', 154],
#  ['Austronesian', 'Mota', 118],
#  ['Austronesian', 'Lubuagan_Kalinga', 154],
#  ['Austronesian', 'Anuta', 159],
#  ['Austronesian', 'Aniwa', 122],
#  ['Austronesian', 'Vaekau-Taumako', 162],
#  ['Austronesian', 'Tetun_Dili_(Tetum)', 114],
#  ['Austronesian', 'Binukid_(Talaandig-Binukid)', 162],
#  ['Austronesian', 'Aklanon', 162],
#  ['Austronesian', 'Lelepa', 138],
#  ['Austronesian', 'North_Marquesan', 145],
#  ['Austronesian', "Ida'an", 160],
#  ['Austronesian', 'Muna', 162],
#  ['Austronesian', 'Nanggu', 54],
#  ['Austronesian', 'Satawalese', 50],
#  ['Austronesian', 'Avava', 46],
#  ['Austronesian', 'Mwotlap', 154],
#  ['Austronesian', 'Tongarevans', 176],
#  ['Austronesian', 'Ulawa', 186],
#  ['Austronesian', 'Sarangani_Blaan', 114],
#  ['Austronesian', 'Chuukese_(Trukese)', 114],
#  ['Austronesian', 'Waia', 50],
#  ['Austronesian', 'Tiri-Mea_(Grand_Couli)', 76],
#  ['Austronesian', 'Hapororan', 264],
#  ['Austronesian', 'Barabet_(Hano)', 144],
#  ['Austronesian', 'Pampanga_(Kampampangan)', 156],
#  ['Austronesian', 'Merei', 14],
#  ['Austronesian', 'Mele-Fila_(Ifira-Mele)', 146],
#  ['Austronesian', 'Indonesian', 162],
#  ['Austronesian', 'Mafea_(Mavea)', 145],
#  ['Austronesian', 'Central_Cagayan_Agta', 162],
#  ['Austronesian', "Ma'anyan", 162],
#  ['Austronesian', 'Padoe', 50],
#  ['Austronesian', 'Sa', 107],
#  ['Austronesian', 'Iban', 162],
#  ['Austronesian', 'Nalik_(Madina)', 119],
#  ['Austronesian', 'Samoan', 196],
#  ['Austronesian', 'Tungag', 50],
#  ['Austronesian', 'Maisin', 230],
#  ['Austronesian', 'Kadai', 64],
#  ['Austronesian', 'Muduapa_(Vitu)', 98],
#  ['Austronesian', 'Atayal', 42],
#  ['Austronesian', 'Tongan', 312],
#  ['Austronesian', 'Tangoa_(Movono)', 18],
#  ['Austronesian', 'Tukang_Besi_South', 48],
#  ['Austronesian', 'Minangkabau', 50],
#  ['Austronesian', 'Munggava_(Rennell)', 138],
#  ['Austronesian', 'Thao', 140],
#  ['Austronesian', 'Gayo', 78],
#  ['Austronesian', 'Buli', 112],
#  ['Austronesian', 'Tomadino', 50],
#  ['Austronesian', 'Fortsenal_(Kiai)', 98],
#  ['Austronesian', 'Bontok', 154],
#  ['Austronesian', 'Avava_(Bangasa_Dialect)', 98],
#  ['Austronesian', 'Manggarai', 114],
#  ['Austronesian', 'Mekeo_(West)', 9],
#  ['Austronesian', 'Sula_Fagudu', 50],
#  ['Austronesian', 'Olal', 98],
#  ['Austronesian', 'Pohnpeian', 55],
#  ['Austronesian', 'Boano_(Sulawesi)', 149],
#  ['Austronesian', 'Marshallese', 96],
#  ['Austronesian', 'Nakanai', 160],
#  ['Austronesian', 'Bau-Jagoi_Bidayuh', 24],
#  ['Austronesian', 'Kei', 245],
#  ['Austronesian', 'Morgan1871_Kusaien', 97],
#  ['Austronesian', 'Balinese', 162],
#  ['Austronesian', 'Sa_a', 138],
#  ['Austronesian', 'Wawonii', 146],
#  ['Austronesian', 'Mangarevans', 173],
#  ['Austronesian', 'Isnag', 162],
#  ['Austronesian', 'Samoan', 138],
#  ['Austronesian', 'Lau_Fijian', 156],
#  ['Austronesian', 'Arosi', 62],
#  ['Austronesian', 'Tasiko', 142],
#  ['Austronesian', 'Kilivila', 96],
#  ['Austronesian', 'Sungwaloge_(Navenvene)', 117],
#  ['Austronesian', 'Landewe', 50],
#  ['Austronesian', 'Nafsan', 101],
#  ['Austronesian', 'Fordata', 237],
#  ['Austronesian', 'Dupaningan_Agat', 130],
#  ['Austronesian', 'Uripiv-Wala-Rano-Atchin', 118],
#  ['Austronesian', 'Paici', 152],
#  ['Austronesian', 'Itbayat', 158],
#  ['Austronesian', 'Sungwaloge_(Nalemba_Simeone_Tari)', 158],
#  ['Austronesian', 'South_Efate', 28],
#  ['Austronesian', 'Umiray_Dumaget_Agta', 114],
#  ['Austronesian', 'Seke_(Ske)', 158],
#  ['Austronesian', 'Kulisusu', 130],
#  ['Austroasiatic', 'Pacoh', 28],
#  ['Austroasiatic', 'Car_Nicobarese', 62],
#  ['Austroasiatic', 'Prai', 364],
#  ['Austroasiatic', 'O_du', 200],
#  ['Austroasiatic', 'Bit', 186],
#  ['Austroasiatic', 'Jahai_(Jehai)', 50],
#  ['Austroasiatic', 'Birhor', 182],
#  ['Tupian', 'Tupí', 197],
#  ['Tupian', 'Aché', 454],
#  ['Tupian', 'Proto_Tupi_Guarani', 91],
#  ['Tupian', 'Tenharim', 170],
#  ['Tupian', 'Emerillon', 75],
#  ['Tupian', 'Tapirapé', 143],
#  ['Tupian', 'Mbyá_Guaraní', 214],
#  ['Tupian', 'Pauserna', 187],
#  ['Tupian', 'Suruí', 145],
#  ['Tupian', 'Anambé', 39],
#  ['Tupian', 'Guajá', 150],
#  ['Tupian', 'Araweté', 153],
#  ['Tupian', 'Sirionó', 271],
#  ['Tupian', 'Paraguayan_Guaraní', 408],
#  ['Tupian', 'Wayampi', 245],
#  ['Tupian', 'Avá_Canoeiro', 33],
#  ...]

# %%
DataFrame = pd.DataFrame(Data, columns = ['Language family', 'Language', 'Richness of the Kin terminology'])
DataFrame
# Out:
#      Language family           Language  Richness of the Kin terminology
# 0      Indo-European             German                              154
# 1      Indo-European             Breton                              490
# 2      Indo-European   Norwegian_Bokmål                              166
# 3      Indo-European          Old_Norse                              160
# 4      Indo-European        Tokharian_A                               24
# ...              ...                ...                              ...
# 1291          Turkic              Kumyk                              230
# 1292          Turkic            Turkish                              176
# 1293          Turkic              Nogai                              324
# 1294          Turkic             Kazakh                              183
# 1295          Turkic  North_Azerbaijani                              318
#
# [1296 rows x 3 columns]

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
DataFrame.to_excel("language_data.xlsx", sheet_name="Kin data", index=False)

# %%
from google.colab import files
files.download("language_data.xlsx")
